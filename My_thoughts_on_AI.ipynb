# %% [markdown]
# <a href="https://colab.research.google.com/github/JackBa1/ai-thoughts/blob/main/My_thoughts_on_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Things I want to do with
# AI
# * Have fun
# * Take over the world
